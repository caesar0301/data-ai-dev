# %%
from nvidia.dali.pipeline import Pipeline
from nvidia.dali import pipeline_def
import nvidia.dali.fn as fn
import nvidia.dali.types as types
import os

image_dir = os.path.join(os.getcwd(), "data/images")
max_batch_size = 2

@pipeline_def
def simple_pipeline():
    jpegs, labels = fn.readers.file(file_root=image_dir, random_shuffle=False)
    images = fn.decoders.image(jpegs, device="cpu")

    return images, labels

# %%
pipe = simple_pipeline(batch_size=max_batch_size, num_threads=1, device_id=0)
pipe.build()
pipe_out = pipe.run()
print(pipe_out)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 pipe = simple_pipeline(batch_size=max_batch_size, num_threads=1, device_id=0)
#       2 pipe.build()
#       3 pipe_out = pipe.run()
#
# File ~/.pyenv/versions/3.12.9/envs/dataai312/lib/python3.12/site-packages/nvidia/dali/pipeline.py:2333, in pipeline_def.<locals>.actual_decorator.<locals>.create_pipeline(*args, **kwargs)
#    2330 pipe = Pipeline(**pipeline_args)
#    2331 _preprocess_pipe_object(pipe, conditionals_on, args, fn_kwargs)
# -> 2333 _generate_graph(pipe, pipe_func, args, fn_kwargs)
#    2334 return pipe
#
# File ~/.pyenv/versions/3.12.9/envs/dataai312/lib/python3.12/site-packages/nvidia/dali/pipeline.py:2186, in _generate_graph(pipe, func, fn_args, fn_kwargs)
#    2172 """Build the graph provided by pipeline definition in `func` within the `pipe`.
#    2173
#    2174 Parameters
#    (...)   2183     Kwargs to `func`
#    2184 """
#    2185 with pipe:
# -> 2186     pipe_outputs = func(*fn_args, **fn_kwargs)
#    2187     if isinstance(pipe_outputs, tuple):
#    2188         po = pipe_outputs
#
# Cell In[27], line 13, in simple_pipeline()
#      10 @pipeline_def
#      11 def simple_pipeline():
#      12     jpegs, labels = fn.readers.file(file_root=image_dir, random_shuffle=False)
# ---> 13     images = fn.decoders.image(jpegs, device="0")
#      15     return images, labels
#
# File ~/.pyenv/versions/3.12.9/envs/dataai312/lib/python3.12/site-packages/nvidia/dali/fn/__init__.py:97, in _wrap_op_fn.<locals>.fn_wrapper(*inputs, **kwargs)
#      95 if _dali_trace.is_tracing_enabled():
#      96     kwargs = {**kwargs, "_definition_frame_end": _dali_trace.get_stack_depth() - 1}
# ---> 97 return op_wrapper(*inputs, **kwargs)
#
# File ~/.pyenv/versions/3.12.9/envs/dataai312/lib/python3.12/site-packages/nvidia/dali/fn/__init__.py:78, in _wrap_op_fn.<locals>.op_wrapper(*inputs, **kwargs)
#      75     init_args["device"] = default_dev
#      77 # TODO(klecki): It is now possible to handle creation of _OperatorInstance directly
# ---> 78 return op_class(**init_args)(*inputs, **call_args)
#
# File ~/.pyenv/versions/3.12.9/envs/dataai312/lib/python3.12/site-packages/nvidia/dali/ops/__init__.py:661, in python_op_factory.<locals>.Operator.__call__(self, *inputs, **kwargs)
#     658 op_instances = []
#     659 for input_set in input_sets:
#     660     op_instances.append(
# --> 661         _OperatorInstance(input_set, arg_inputs, args, self._init_args, self)
#     662     )
#     664 # Tie the instances together
#     665 relation_id = op_instances[0].relation_id
#
# File ~/.pyenv/versions/3.12.9/envs/dataai312/lib/python3.12/site-packages/nvidia/dali/ops/__init__.py:400, in _OperatorInstance.__init__(self, inputs, arg_inputs, arguments, _processed_arguments, op)
#     397 self._spec.AddArg("preserve_name", not self._autoname)
#     398 _process_arguments(op._schema, self._spec, arguments, op._operator_name())
# --> 400 self._inputs = _process_inputs(op._schema, self._spec, inputs, op._operator_name())
#     401 self._inputs += _process_argument_inputs(
#     402     op._schema, self._spec, arg_inputs, op._operator_name()
#     403 )
#     405 _handle_op_deprecation(
#     406     self._op.schema, _processed_arguments["_module"], _processed_arguments["_display_name"]
#     407 )
#
# File ~/.pyenv/versions/3.12.9/envs/dataai312/lib/python3.12/site-packages/nvidia/dali/ops/__init__.py:327, in _process_inputs(schema, spec, inputs, operator_name)
#     325     if not isinstance(inp, _DataNode):
#     326         raise TypeError(f"Expected inputs of type 'DataNode'. Received input of type '{inp}'.")
# --> 327     spec.AddInput(inp.name, inp.device)
#     328 return list(inputs)
#
# ValueError: Unsupported device type: "0".
